# %%
def player():
    reply_player=input("Are you ready to solve maths? y/n")
    if reply_player=="y":
        player_name=input("Thank you. What is your name?")
        print(f"Ok. {player_name}, please, wait a second.")
        time.sleep(1) 
        player_choice=input("Which one you wanna do: Write '+' for Addition or '-'Subtraction")
        if player_choice=="+":
            print("Addition is starting")
            time.sleep(2)
            addition()
                
        elif player_choice=="-":
            print ("Subtraction is starting")
            time.sleep(2)
            subtraction()
        else:
            print("Please, + y or -")
            player()
        
    elif reply_player=="n":
        print("Bye Bye. ")
        
        
    else: 
        print("Please, just y or n")
        player()

        
import random
import time 

def addition():
    
    Range1=int(input("For first number, write your range here. From 1 to ? ---->  "))
    Num1=random.randint(1,Range1)
    Range2=int(input("For second number, write your range here. From 1 to ? ---->  "))
    Num2=random.randint(1,Range2)
    print(f"This question is for you :  {str(Num1)} + {str(Num2)} = ? ")
    player_result=int(input("Please, write here your result  ---->  "))
    comp_result=int(Num1) + int(Num2)
    
    if player_result==comp_result:
        print("Your solution is right!!! You are genuis.")
        
        def p_choice2():
            player_choice2=input("Do you wanna play again? y/n")
            if player_choice2=="y":
                print("Next question is coming. Wait a second.")                    
                time.sleep(2)
                addition()  
            elif player_choice2=="n":
                player_choice3=input("Do you wanna solve subtraction problems? y/n ")
                def p_choice3():
                    if player_choice3=="y":
                        subtraction() 
                    elif player_choice3=="n":
                        print("Bye. Bye.")  
                    else:
                        print("Please write just y/n ")
                        
                p_choice3()
                
            else:
                print("Please write just y/n ")
                p_choice2()
       
        p_choice2()
        

    elif player_result !=comp_result:
        print(f"The result was {comp_result} \n Don't be sad! Try again.")
        def p_choice5():
            player_choice5=input("Do you wanna play again? y/n")
            if player_choice5=="y":
                print("Next question is coming. Wait a second.")                  
                time.sleep(2)
                addition()
            elif player_choice5=="n": 
                def p_choice6():
                    player_choice6=input("Do you wanna solve subtraction problems? y/n ")
                    if player_choice6=="y":
                        subtraction()
                    elif player_choice6=="n": 
                        print("Bye. Bye.")            
                    else:
                        print("Please write just y/n ")
        
            else:
                print("Please write just y/n ")
                p_choice5()
        p_choice5()
    else:
        print("Please write just y/n ")
                              
def subtraction():
    
    Range1=int(input("For first number, write your range here. From 1 to ? ---->  "))
    Num1=random.randint(1,Range1)
    Range2=int(input("For second number, write your range here. From 1 to ? ---->  "))
    Num2=random.randint(1,Range2)
    
    if Num1>Num2:
        print(f"This question is for you :  {str(Num1)} - {str(Num2)} = ? ")
    else: 
        print("The first number should greater than the second one. Please try again.")
        subtraction()
        
    player_result=int(input("Please, write here your result  ---->  "))
    comp_result=int(Num1) - int(Num2)
    
    if player_result==comp_result:
        print("Your solution is right!!! You are genuis.")
        
        def p_choice12():
            player_choice12=input("Do you wanna play again? y/n")
            if player_choice12=="y":
                print("Next question is coming. Wait a second.")                    
                time.sleep(2)
                addition()  
            elif player_choice12=="n":
                player_choice13=input("Do you wanna solve addition problems? y/n ")
                def p_choice13():
                    if player_choice13=="y":
                        addition() 
                    elif player_choice13=="n":
                        print("Bye. Bye.")  
                    else:
                        print("Please write just y/n ")
                        
                p_choice13()
                
            else:
                print("Please write just y/n ")
                p_choice12()
       
        p_choice12()
        

    elif player_result !=comp_result:
        print(f"The result was {comp_result} \n Don't be sad! Try again.")
        def p_choice15():
            player_choice15=input("Do you wanna play again? y/n")
            if player_choice15=="y":
                print("Next question is coming. Wait a second.")                  
                time.sleep(2)
                subtraction()
            elif player_choice15=="n": 
                def p_choice16():
                    player_choice16=input("Do you wanna solve addition problems? y/n ")
                    if player_choice16=="y":
                        addition()
                    elif player_choice16=="n": 
                        print("Bye. Bye.")            
                    else:
                        print("Please write just y/n ")
        
            else:
                print("Please write just y/n ")
                p_choice15()
        p_choice15()
    else:
        print("Please write just y/n ")
        

player()
